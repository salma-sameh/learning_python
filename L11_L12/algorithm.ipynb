# %%
#Bubble Sort
def bubble_sort(arr):
    for i in range(len(arr)):
        for j in range(len(arr)-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]

# %%
#Merge Sort
def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr)//2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])

    return merge(left, right)

def merge(l, r):
    result = []
    while l and r:
        result.append(l.pop(0) if l[0] < r[0] else r.pop(0))
    return result + l + r

# %%
#Quick Sort
def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[0]
    left = [x for x in arr[1:] if x <= pivot]
    right = [x for x in arr[1:] if x > pivot]
    return quick_sort(left) + [pivot] + quick_sort(right)

# %%
#Heap Sort
import heapq

def heap_sort(arr):
    heapq.heapify(arr)
    return [heapq.heappop(arr) for _ in range(len(arr))]

# %% [markdown]
# Assignment 1: Benchmark all sorting algorithms with different dataset sizes.

# %% [markdown]
# Assignment 2: Implement hybrid sorting algorithm combining two methods.

# %% [markdown]
# L12

# %%
#Linear Search
def linear_search(arr, x):
    for i in arr:
        if i == x:
            return True
    return False

# %%
#Binary Search
def binary_search(arr, x):
    low, high = 0, len(arr)-1
    while low <= high:
        mid = (low + high)//2
        if arr[mid] == x:
            return True
        elif arr[mid] < x:
            low = mid + 1
        else:
            high = mid - 1
    return False

# %%
#Fibonacci (DP – Memoization)
memo = {}
def fib(n):
    if n <= 1:
        return n
    if n not in memo:
        memo[n] = fib(n-1) + fib(n-2)
    return memo[n]

# %%
#Fibonacci (Tabulation)
def fib_tab(n):
    dp = [0,1]
    for i in range(2,n+1):
        dp.append(dp[i-1] + dp[i-2])
    return dp[n]
